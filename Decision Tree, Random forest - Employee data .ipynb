# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
employee=pd.read_csv("C:/Users/NADEEM/Downloads/employee (1).csv")

# %%
employee.head()
# Out:
#    ï»¿Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
employee.shape
# Out:
# (1470, 35)

# %%
employee.describe()
# Out:
#             ï»¿Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
employee.isnull().sum()
# Out:
# ï»¿Age                      0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
for i in employee.describe().columns:
    sns.boxplot(employee[i])
    plt.show()
# Out:
# C:\Users\NADEEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NADEEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NADEEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(10,6))
for i in employee.describe().columns:
    sns.countplot(employee[i])
    plt.show()
# Out:
# C:\Users\NADEEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NADEEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\NADEEM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
employee.Education.unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
employee.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
employee.columns
# Out:
# Index(['ï»¿Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
employee.nunique()
# Out:
# ï»¿Age                        43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
employee.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'],axis=1,inplace=True)

# %%
employee.columns
# Out:
# Index(['ï»¿Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
employee.rename(columns={'ï»¿Age':'Age'},inplace=True)

# %%
employee.loc[employee.Attrition=='Yes','Attrition']=1
employee.loc[employee.Attrition=='No','Attrition']=0

# %%
employee.Attrition.unique()
# Out:
# array([1, 0], dtype=object)

# %%
employee=pd.get_dummies(employee,drop_first=True)

# %%
from sklearn.model_selection import train_test_split

# %%
emp=employee.copy()

# %%
train_X=emp.drop(['Attrition_1'],axis=1)
train_Y=emp['Attrition_1']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(train_X,train_Y,test_size=0.2)

# %%
print(X_train.shape)
# Out:
# (1176, 44)

# %%
from sklearn import tree

# %%
dt=tree.DecisionTreeClassifier()

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred=dt.predict(X_test)

# %%
from sklearn import metrics

# %%
print('Accurance : ',metrics.accuracy_score(Y_test,Y_pred))
#print('Accurance : ',metrics.accuracy_score(Y_test,Y_pred))
#print('Accurance : ',metrics.accuracy_score(Y_test,Y_pred))
# Out:
# Accurance :  0.8095238095238095

# %%
# !pip install graphviz
# import graphviz
# from sklearn.externals.six import Stringio
# from IPython.display import Image
# from sklearn.tree import export_graphviz
# import pydotplus

# %%
tree.export_text(dt)
# Out:
# '|--- feature_43 <= 0.50\n|   |--- feature_16 <= 1.50\n|   |   |--- feature_5 <= 58.50\n|   |   |   |--- feature_17 <= 3.50\n|   |   |   |   |--- feature_14 <= 3.50\n|   |   |   |   |   |--- class: 1\n|   |   |   |   |--- feature_14 >  3.50\n|   |   |   |   |   |--- class: 0\n|   |   |   |--- feature_17 >  3.50\n|   |   |   |   |--- feature_6 <= 2.50\n|   |   |   |   |   |--- class: 1\n|   |   |   |   |--- feature_6 >  2.50\n|   |   |   |   |   |--- class: 0\n|   |   |--- feature_5 >  58.50\n|   |   |   |--- feature_42 <= 0.50\n|   |   |   |   |--- feature_5 <= 96.50\n|   |   |   |   |   |--- class: 0\n|   |   |   |   |--- feature_5 >  96.50\n|   |   |   |   |   |--- class: 1\n|   |   |   |--- feature_42 >  0.50\n|   |   |   |   |--- feature_1 <= 249.50\n|   |   |   |   |   |--- class: 1\n|   |   |   |   |--- feature_1 >  249.50\n|   |   |   |   |   |--- feature_18 <= 2.50\n|   |   |   |   |   |   |--- class: 1\n|   |   |   |   |   |--- feature_18 >  2.50\n|   |   |   |   |   |   |--
# ...

# %%
#Varun Anguralia12:14
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt, 
#                    feature_names=train_X.feature_names,  
#                    class_names=iris.target_names,
                   filled=True)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=50,bootstrap=False)

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=False, n_estimators=50)

# %%
Y_Pred=rf.predict(X_test)

# %%
print('Accuracy : ',metrics.accuracy_score(Y_test,Y_Pred)*100)
# Out:
# Accuracy :  88.77551020408163

# %%
pd.crosstab(Y_test,Y_Pred)
# Out:
# col_0          0   1
# Attrition_1
# 0            249   5
# 1             28  12
